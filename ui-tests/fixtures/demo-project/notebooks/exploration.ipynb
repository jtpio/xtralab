# %% [markdown]
# # Exploring Acme Regional Sales
#
# A quick look at revenue across regions for Q1 2024.

# %%
from acme.loader import load_sales
from acme.metrics import revenue_by_region, top_region

sales = load_sales("../data/sales.csv")
len(sales)
# Out:
# 8

# %% [markdown]
# ## Revenue by region

# %%
revenue_by_region(sales)
# Out:
# {'North': 39350.0, 'South': 30250.0, 'East': 44900.0, 'West': 26350.0}

# %% [markdown]
# The strongest region this quarter:

# %%
top_region(sales)
# Out:
# 'East'
